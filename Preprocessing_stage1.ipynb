# %% [markdown]
# ## Feedback Preprocessing - Stage 1
#
# **BACKGROUND**:
#
# The preprocessing of the feedback data was done through the following stages:
#
# - Stage 0: The initial raw data files containing the feedback were sourced from Monash University's Master of Data Science course. The required data was isolated and filtered out from the original data. Additionally, the feedback text contained a lot of dirty characters including HTML code. Through a meticulous data wrangling process, these the feeback text was cleaned and brought into a final form which was to be labelled.
#
# The feedback data was labelled with the help of a lightweight text annotation tool called Yedda. Yedda was customised to include the below 8 rubrics of Learner-centred feedback:
#
# - **Focus on Future Impact**:
#    - Impact 1: Provide actionable information for improving on specific aspects of the student's task
#    - Impact 2: Provide actionable information for improving the overall task, in line with the learning outcomes.
#    - Impact 3: Provide actionable information for the student to improve certain skills and strategies beyond the scope of the learning outcomes.
#
# - **Sensemaking**:
#   - Sensemaking 1: Higlight strengths and weaknesses of specific aspects of the student's work.
#   - Sensemkaing 2: Highlight the overall strengths and weaknesses of the student's work with respect to the learning outcomes.
#
# - **Support Agency**:
#   - Agency 1: Encourage the student to look up the academic material or feedback, look up sources on the internet for more information or reach out to the teacher regarding the feedback or learning outcomes.
#   - Agency 2: Provide statements that affirm and acknowledge the student's work.
#   - Agency 3: Include comments that help foster a closer teacher-student relationship.
#
# The Yedda tool exports the labelled data as `.sentence` files. For more information on the usage of this tool, please click here: [Yedda](https://github.com/jiesutd/YEDDA)
#
# In this notebook, we will load the `.sentence` files that have been generated from the annotation process. For better manoeuvrability, we can use the Pandas library to load these files into dataframes and then combine them into a single dataframe with 1000 annotated text samples.
#
# The Yedda exported `.sentence` files were converted into standard text files before loading them here.
#
# **Note**: The code for Preprocessing stage 0 could not be shared in this repository due to confidentially reasons. FOr any queries regarding the preprocessing steps, please reach out to me on my email ID: siddharthgupte@hotmail.com
#
# After the completion of the steps in this notebook, the stage 1 file was converted to a stage 2 file in excel by adding a new column called `FeedbackCode`. To view this column, please refer to the `stage2.csv` file in this repository.
#
# First, let us load the required libraries including `Pandas` and `itertools`.

# %%
# Loading the required libraries
import pandas as pd
import re
import itertools

# %% [markdown]
# ### 1. Loading the Annotated Text
#
# To load the annotated `.txt` files, we need to load them into lists that can be combined later.

# %%
# Specifying the column name for the dataframes
colnames=['Sentence', 'Rubric']

# %%
# Loading labelled data file 1
with open("./LabelledFeedback/1-100_labelled.txt") as file1:
    dat1 = [line.rstrip() for line in file1]

# %%
# Loading labelled data file 2
with open("./LabelledFeedback/101-200_labelled.txt") as file2:
    dat2 = [line.rstrip() for line in file2]

# %%
# Loading labelled data file 3
with open("./LabelledFeedback/201-300_labelled.txt") as file3:
    dat3 = [line.rstrip() for line in file3]

# %%
# Loading labelled data file 4
with open("./LabelledFeedback/301-400_labelled.txt") as fil4:
    dat4 = [line.rstrip() for line in fil4]

# %%
# Loading labelled data file 5
with open("./LabelledFeedback/401-500_labelled.txt") as file5:
    dat5 = [line.rstrip() for line in file5]

# %%
# Loading labelled data file 6
with open("./LabelledFeedback/501-600_labelled.txt") as file6:
    dat6 = [line.rstrip() for line in file6]

# %%
# Loading labelled data file 7
with open("./LabelledFeedback/601-700_labelled.txt") as file7:
    dat7 = [line.rstrip() for line in file7]

# %%
# Loading labelled data file 8
with open("./LabelledFeedback/701-800_labelled.txt") as file8:
    dat8 = [line.rstrip() for line in file8]

# %%
# Loading labelled data file 9
with open("./LabelledFeedback/801-900_labelled.txt") as file9:
    dat9 = [line.rstrip() for line in file9]

# %%
# Loading labelled data file 10
with open("./LabelledFeedback/901-1000_labelled.txt") as file10:
    dat10 = [line.rstrip() for line in file10]

# %%
# Loading labelled data file 11
with open("./LabelledFeedback/1001-1039_labelled.txt") as file11:
    dat11 = [line.rstrip() for line in file11]

# %%
# Loading labelled data file 12
with open("./LabelledFeedback/1040-1079_labelled.txt") as file12:
    dat12 = [line.rstrip() for line in file12]

# %% [markdown]
# In the previous step, we loaded each of the labelled data files as lists. We can use the `itertools` library to combine these lists into a single master list.

# %%
# Creating a master list from the lists of feedbacks
full_dat = list(itertools.chain(dat1, dat2, dat3, dat4, dat5, dat6, dat7, dat8, dat9, dat10, dat11, dat12))

# Checking the length of the master list
len(full_dat)
# Out:
# 12171

# %%
# Checking the master list
full_dat
# Out:
# ['Yuejing more in depth analysis is required and see how you can link key concepts. 58.33\tSensemaking 1&Impact 1',
#  '',
#  '\ufeffTeam 1 requested to re-do their workbook 3 to better their original mark of 55.\tImpact 1',
#  'The team submitted the workbook 23 days after the submission date. KV 59\tSensemaking 2',
#  '',
#  'Risk assessment and report needs work as discussed in tutorial 70\tSensemaking 1',
#  '',
#  '"Good effort, Please refer to detailed feedback file attached.\tAgency 2&Agency 1',
#  'Best WishesNergiz." 60.6\tAgency 3',
#  '',
#  '"lacked depth and detail.\tSensemaking 1',
#  'Failed to cite, and use the prescribed texts so the answers were over simplified and not in accordance with ther learning of this course.\tSensemaking 2',
#  'DevOSps is a hybrid between Project managemetn and SDLC.\tSensemaking 1',
#  'EA provides detail design and requirements for planning as agreed by software developers and IT operations.\tSensemaking 1',
#  'YOu missed several very vital points" 54.8\tSensemaking 1',
#  '',
#  '"PMBOK (PMI 2013) is a super-ceded reference and is withdraw. You cannot use this as a refernce unless speaking in historical terms.\tSensemaking 1&Impact 1',
#  'You have reduced DevOps to the Waterfall vs Agile argument, which is wrong. Devops is the process of EA conceptual design developing requirements that can be planned (using predictive PM methodology) and the delivery is via a SDLC (typically Agile). It is in this hybrid process that EA and cybersecurity are planned for delivery.\tSensemaking 1&Impact 1',
#  'If you do not understand EA design priciples as taught in this subject, you cannot describe leading edge DevOps concepts." 50.28\tImpact 1',
#  '',
#  'good in general.\tAgency 2',
#  'Wbs needs work as discussed in tutorial. 75\tSensemaking 1',
#  '',
#  'Feedback as provided in consultation.; 70\tAgency 1',
#  '',
#  'Both product scope and WBS have room for improvement 75\tSensemaking 1',
#  '',
#  'Team 1 requested to re-do the workbook 2 to better their original fail mark.\tImpact 2',
#  'The team submitted the workbook 31 days after the submission date. KV 50\tSensemaking 2',
#  '',
#  '"Good effort all up, as I mentioned in consultation - Dont allocate 15% to risk mitigation, you need to calculate this.\tAgency 2&Impact 1',
#  'Very good effort with this workbook." 80\tAgency 2',
#  '',
#  'Cost report needs work as discussed in tutorial. ; 70\tSensemaking 1',
#  '',
#  '"Hui Pan, a reasonable attempt - you need t0 show more depth and analysis in your writing.\tAgency 2&Impact 1',
#  'However, you made a good attempt at representing the information in the visual diagram.;" 63.35\tSensemaking 1',
#  '',
#  'Both product scoping and WBS have some room for improvements 80\tSensemaking 1',
#  '',
#  'Cost report needs work as discussed in tutorial. ; 70\tSensemaking 1',
#  '',
#  'You started off really strong with this workbook.\tSensemaking 1',
#  'Q1 and Q2 were great.\tSensemaking 1',
#  'You missed a big trick in combining labour into Q3 onwards which unfortunately cost you in terms of marks.\tSensemaking 1',
#  'You have thought well about the labour cost rates and the non labour costs.\tSensemaking 1',
#  'Your report became very disjointed and hard to follow on the final few pages although I was able to find question 5 in the end. 81\tSensemaking 1',
#  '',
#  'You put in a really good effort for this workbook.\tAgency 2',
#  'The costs you used were well sourced and you applied them to your schedule well.\tSensemaking 1',
#  'You considered different cost types including the risk provisioning.\tSensemaking 1',
#  'Unfortunately you did not answer two of the questions and were penalised heavily for that!\tSensemaking 2',
#  'This work you have done here regarding the report format will serve you well for the final report. 49\tImpact 2',
#  '',
#  '"overall an excellent attempt to develop more reflective (critical thinking)\tSensemaking 2',
#  'Some of the insights provided are important and the learning you have made is excellent.\tSensemaking 1',
#  'Better academic writing in using secondary refences to strengthen your discussion will provide higher marks.\tImpact 1',
#  'Still, this is a significant improvement in refelctive thinking." 68.2\tSensemaking 2',
#  '',
#  'Feedback as provided in consultation.\tAgency 1',
#  'Predecessors are missing from the Gantt chart.; 68\tSensemaking 1',
#  '',
#  '"See attached feedback.\tAgency 1',
#  'Please note that all project teams were provided feedback from KV in consultations held in the week comm 19/4, and provided a summary version of their feedback at that time. KV" 57\tAgency 1',
#  '',
#  'Paper was moderated by all tutors. 67.49\tAgency 1',
#  '',
#  'DevOps doesn’t = Agile. Agile is part of the DevOSp cycle as is predictive planning. The design model of EA is important in this issue\tSensemaking 1&Impact 1',
#  'There is a lack of understanding on DevOPS and EA and requirements development.\tSensemaking 1',
#  'The assignment is disjointed and poorly developed.\tSensemaking 2',
#  ';Some of your references are ??? A printer as a reference. YOu lost marks in that section.\tSensemaking 1',
#  'You need to watch how you use citations.\tImpact 1',
#  'YOu are on the limit of having to repeat as there is too much copying of refewrnces. They need to be rewritten. 55.04\tSensemaking 1&Impact 1',
#  '',
#  'good in general.\tAgency 2',
#  'Wbs needs work as discussed in tutorial. 75\tSensemaking 1',
#  '',
#  '"Xinyang, more depth of analysis is required here.;" 57.03\tSensemaking 2',
#  '',
#  'Feedback as provided in consultation.; 65\tAgency 1',
#  '',
#  '"This assignment fails to answer the questions to the depth required.\tSensemaking 2',
#  'Fails to show any knowledge of DevOps, the place of SDLC in DevOps and EA design concepts as related to the development on conceptual design, non functional and functional requirements.\tSensemaking 1',
#  'LAcks research and approapriate critical thinking." 19.25\tSensemaking 1',
#  '',
#  'good submission.\tAgency 2',
#  'Needed some more indepth discussion and particularly on EA conceptual design as the driver for the functional and non fucntional requiremnts driver.\tSensemaking 1',
#  'Also DevOps intergrates Agile (SDLC) into a planned environment (predictive PM) and organisations need to define the levels of planning apprioapriately.; 80.38\tImpact 1',
#  '',
#  'Feedback as provided in consultation.; 65\tAgency 1',
#  '',
#  '"NOTE: O',
#  '2 O',
#  'days O',
#  'late O',
#  'with O',
#  'medical O',
#  'cert O',
#  'granted.; O',
#  'Please review the attached ""Turnitin"" download.\tAgency 1',
#  'While the coversheet has contributed significantly to the high score, you will be able to see that there is also some poor practise in developing content from a reference that needs to be addressed. This is a development skill that will need to be addressed BEFORE the next assignment.\tSensemaking 1&Impact 2',
#  ';Overall, some good work, however many easy marks were lost in a non exsistant exec summary (the abstract did not provide the required information satisfactorily) the introduction was poor.\tAgency 2&Sensemaking 1',
#  'While it seems your research skills are good and finding definitions and anlysis, htere is a fundamential issue with your DevOps understanding. ;THis created issues with yiour descriptions of how DevOps and EA fit within PM. The key is understanding that EA manages the business requyirements at coneptual level (you did not really discuss this) and these requirements are of a functional and non functional nature. Cybersecurty is part of this. PM manages the planning and delivery of these requirements.;" 58.9\tSensemaking 1&Impact 1',
#  '',
#  'Generally a reasonable effort.\tAgency 2',
#  'Starting to develop analytical thinking in writing although writing is still heavily descriptive.\tSensemaking 1',
#  'Better use of in-text citations and the secondary references to develop your comments more as informed discussion rather than repenting the writing as descriptive opinion.; 60.9\tSensemaking 1',
#  '',
#  'Feedback as provided in consultation.\tAgency 1',
#  'Visibility of WBS needs to be addressed.; 72\tSensemaking 1',
#  '',
#  'Both product scope and WBS has room for improvement 75\tSensemaking 1',
#  '',
#  '"Referencing is not to APA standards.\tSensemaking 1',
#  'Overall a failure to fully inderstand the DevOps conepts taught in this course and the role of EA in defining thre requirenments that allow planning, via predicitive PM methodology for delivery of the SDLC (typically Agile) .\tSensemaking 1',
#  'No discussion on EA conceptual design and requirements development of non functional and functional requirements.\tSensemaking 1',
#  'Cybersecurity is a non functional requirement that needs to be developed prior to Logical and physical design in the SDLC." 53.15\tImpact 1',
#  '',
#  '"Overall, your PM knowledge application is well balanced across all knowledge areas.\tSensemaking 2',
#  ';Your critical skills is at developing level;\tSensemaking 1',
#  'Overall, reasonable.\tAgency 2',
#  'Lost marks from being too brief in anlysis really.\tSensemaking 1',
#  'In essence the report contsined most infromation, however the analysis of application needed further depth.\tSensemaking 2&Sensemaking 1',
#  'Quality of report in presen tation was average and needs work on. ;" 75.12\tSensemaking 1',
#  '',
#  '"as per the general video comments, particularly with regard to using provided papers and referencing.;" 70\tAgency 1',
#  '',
#  '"Overall, lacks understanding of the concepts as taught in this subject.\tSensemaking 2',
#  'Fails to discuss the role of EA in conceptural design, functional and non fucntional requirements.\tSensemaking 1',
#  'Has not shown any evidence of understanding the concepts of DevOps, Predictive project management and SDLC hybrid concepts.\tSensemaking 1',
#  'Turnitin Score (44% excluding the cover sheet) is too high and shows poor acdemic skill." 38.25\tSensemaking 2',
#  '',
#  '"Overall, your PM knowledge application is inconsistent/poor across all knowledge areas.\tSensemaking 2',
#  ';Your critical skills need significant improvement\tSensemaking 1',
#  'This assignment is poor and not to masters level work.\tSensemaking 2',
#  'You have relied on using past semesters submissions as a guide without realising that the questions have changed.\tSensemaking 2',
#  'You lost a possible 14 % by not answering the SOW section and providing an Exec Summary.\tSensemaking 1',
#  'You have used last semesters Costing spreadsheet and failed to recognise ther question has changed.\tSensemaking 1',
#  'Risk section is poor and lacks detail.\tSensemaking 1',
#  'GAntt chart is incomplete.\tSensemaking 1',
#  'In general, this report lacks the level of definitiona nd description required from a masters students.\tSensemaking 2',
#  'There is very little description and nearly no anlaysis.\tSensemaking 1',
#  'You are expected to take the information and discuss how the application of the techniques occurs.\tImpact 1',
#  ';Due to high Turnitin Score analysis, shows copying form sources and other students work. 15 % deduction applied." 37.84\tSensemaking 2',
#  '',
#  '"Turnitin similarity is high, Paraphrase your answers" 65\tSensemaking 2&Impact 2',
#  '',
#  'Q 10 is poorly answered. Lacks understanding.\tSensemaking 1',
#  'Otherwise generally good\tAgency 2',
#  'Moodle corrupted the word doc. 80\tSensemaking 2',
#  '',
#  '"See attached feedback.\tAgency 1',
#  'Please note that all project teams were provided feedback from KV in consultations, and provided a copy of their feedback at that time. KV" 63\tAgency 1',
#  '',
#  'Feedback as provided in consultation.; 70\tAgency 1',
#  '',
#  '"Good effort, Please refer to detailed feedback file attached.\tAgency 2&Agency 1',
#  'Best WishesNergiz." 70.06\tAgency 3',
#  '',
#  '"as per the general video comments, particularly with regard to using provided papers and referencing. Needs more detail.\tSensemaking 1',
#  'APA standards need to be applied in referencing" 50\tImpact 1',
#  '',
#  '"overall, lacks depth and did not answer all questions fully.;" 54.8\tSensemaking 1&Sensemaking 2',
#  '',
#  '" You\'ve received good marks for the content part of each question as you have demonstrated that you understand each concept and explained it well.\tSensemaking 2',
#  'Areas O',
#  'for O',
#  'improvement O',
#  'that O',
#  'will O',
#  'help O',
#  'you O',
#  'with O',
#  'the O',
#  'following O',
#  'assessments: O',
#  'Include at least one citation for each question and make sure you both cite in-line and reference correctly;\tImpact 1',
#  'Add figure/table numbers and describe each figure and table; and for maximum marks, You need to discuss (not just describe) elements about each question. " 64.75\tImpact 1&Impact 2',
#  '',
#  '"Team 1 decisions re marking were as follows, and is recorded in MS TEAMS:\tAgency 1',
#  "i) to split the completion of Ass 2B report into individual parts [(this was agreed to by the tutor (KV) and Chief Examiner (CC)] - the parts/split is recorded in the Appendix of Team 1's submitted report;\tAgency 1",
#  'ii) to be individually marked for these parts;\tAgency 1',
#  'iii) it was also decided to share equally the marks for reference and language proficiency. KV" 54\tAgency 1',
#  '',
#  '"Zhengyang, you write really well - see how you can improve on providing depth in writing by giving examples or use comparison techniques to show your own understanding.\tSensemaking 1&Impact 3',
#  'Good work.;" 70\tAgency 2',
#  '',
#  '"Your schedule was reasonable, And I\'m happy that you are demonstrated your ability to use Project.\tSensemaking 1',
#  'Your resource allocation was underbaked.\tSensemaking 1',
#  'A lot more will become clear when you have experience using this tool for commercial projects.\tImpact 3',
#  'The rest of your sections were generally not too bad.\tSensemaking 1',
#  'You really need to tighten up your citations you are losing easy marks.\tImpact 1',
#  'Also I am still seeing no evidence of ciritcal analysis.\tSensemaking 1',
#  'Finally, just dumping your gannt chart with no explanation was not a good move." 56.39\tSensemaking 1',
#  '',
#  'Q 10 is poorly answered.Lacks understanding.\tSensemaking 1',
#  'Otherwise generally good\tAgency 2',
#  'Moodle corrupted the word doc. Please use Pdfs 80\tSensemaking 2',
#  '',
#  'As per attached. 60.4\tAgency 1',
#  '',
#  '"good in general.\tAgency 2',
#  'risk register good, lacks detailed analysis and description" 70\tSensemaking 1',
#  '',
#  '"See attached feedback.\tAgency 1',
#  'Please note that all project teams were provided feedback from KV in consultations held in the week comm 19/4, and provided a summary version of their feedback at that time. KV" 50\tAgency 1',
#  '',
#  'Refer to attached. 51\tAgency 1',
#  '',
#  'Feedback as provided in consultation. 65\tAgency 1',
#  '',
#  'good in general.\tAgency 2',
#  'Wbs needs work as discussed in tutorial.; 75\tSensemaking 1',
#  '',
#  'Feedback as provided in consultation.\tAgency 1',
#  'Predecessors are missing from the Gantt chart.; 68\tSensemaking 1',
#  '',
#  '"Overall, your PM knowledge application is well balanced across all knowledge areas.\tSensemaking 2',
#  ';Your critical skills is at developing level;\tSensemaking 1',
#  'Overall, reasonable.\tAgency 2',
#  'Lost marks from being too brief in anlysis really.\tSensemaking 1',
#  'In essence the report contsined most infromation, however the analysis of application needed further depth." 61.94\tSensemaking 2&Sensemaking 1',
#  '',
#  'Both product scope and WBS has room for improvement 75\tSensemaking 1',
#  '',
#  '"Jiayu, a good attempt, you would need to show more depth and see how you can identify key and relevant concepts in this area.;" 64.1\tAgency 2&Impact 1',
#  '',
#  'late submission.\tSensemaking 2',
#  'Make sure to submit before deadline.\tImpact 2',
#  'Good luck. 0\tAgency 3',
#  '',
#  '"Hi Sifan,We definitely will consider the contribution from each team member, and influenced their individual mark.\tAgency 1',
#  'Also please let all team members noticed that this is teamwork, if one person is not responsible for the team project, and your team project can not deliver as an ""expected project"",; the team mark will be influenced as well.\tImpact 2',
#  ';You have done a good job, please keep up the good work.\tAgency 2',
#  'Cheers,Lee" 65\tAgency 3',
#  '',
#  'Late entry 0\tSensemaking 2',
#  '',
#  'Thanks for sharing.\tAgency 3',
#  "It's amazing to hear to your experience and journey with this unit.\tAgency 3",
#  'All the best for your future endeavours.\tAgency 3',
#  'Keep in touch. :) 65\tAgency 3',
#  '',
#  'No Submission 0\tSensemaking 2',
#  '',
#  'Thanks for the diary.-VT 65\tAgency 3',
#  '',
#  'Good luck and best wishes for the future it has been a pleasure working with you.P.B. 70\tAgency 3',
#  '',
#  '"You have written more in line with FIT5122, there is less reflection more of a summary of things that you did.;" 55\tSensemaking 2',
#  '',
#  'Late Submission. 0\tSensemaking 2',
#  '',
#  'thanks for your diary.\tAgency 3',
#  'Elaborate your reflection a little.\tSensemaking 2',
#  'Just work on the sentence structure a little.-VT 55\tSensemaking 1',
#  '',
#  'Good job Xiaoming .\tAgency 2',
#  'Keep it up.\tAgency 2',
#  'All the best! 70\tAgency 3',
#  '',
#  'How how do you plan on overcoming these communication/time differences.\tImpact 1',
#  'How do you feel about it? Satisfied/not satisfied.\tImpact 1',
#  'Dig deep into your emotions.\tImpact 1',
#  'You can also reflect on what have you learnt in your studios/lecture.\tImpact 1',
#  'How has it helped you?\tImpact 1',
#  'Good overall.; 60\tAgency 2',
#  '',
#  '"There was lot of re-iteration notice in your reflection.\tSensemaking 1',
#  'Instead try to reflect more on your learnings from these activities, team dynamics, your action plan etc.;" 50\tImpact 1',
#  '',
#  '"Hi Ajay,Your diary is a little bit descriptive,;\tSensemaking 1',
#  ';try to use a few sentences to describe a few important incidents and then focus on;what did you;feel, why did you have that feeling and what needs to improve to help your team.\tImpact 1',
#  'Besides, try to reflect deeply on how these learnings can help your team and your project.\tImpact 1',
#  'For the action plan, you need to have some strategies to overcome some incidents which happened before, for example, if a similar issue occurs in the future, what actions will you take or what can you do to avoid this happen again." 70\tImpact 1',
#  '',
#  '"thanks for your diary.\tAgency 3',
#  'Your reflection is good maybe you can elaborate a little on some parts.\tSensemaking 2',
#  'Also, there has been some improvement in your action plan as well.\tSensemaking 1',
#  'Just work on the sentence structure a little.-VT" 70\tImpact 1',
#  '',
#  'Thanks for the diary.-VT 65\tAgency 3',
#  '',
#  '"Hey Wenyuan,;I would be happy to give you some feedback regarding your diaries.\tAgency 3',
#  'I feel that your diaries mostly comprise of you stating what has happened in class or the team, but doesn\'t contain much ""reflection"" on those aspects.\tSensemaking 2',
#  'For instance, you faced technical issues which took a long time to fix, thus hindering your progress - how did you feel about that? Did you feel angry? Worried?\tImpact 1',
#  'Why did you and the team face tech issues in the first place? What went wrong? Could it have been avoided?\tImpact 1',
#  'How did your team members react to this? How did their reactions make you feel?\tImpact 1',
#  'What did you discover about yourself and your skills from this experience?\tImpact 1',
#  'These are the type of questions you should be asking yourself while reflecting.\tImpact 1',
#  'You need to dig deeper to come up with a proper reflection.\tImpact 2',
#  'I would recommend googling ""Gibbs cycle of reflection"" and try to apply that to your diaries. " 65\tAgency 1&Impact 1',
#  '',
#  '"Hi,Great job on submitting your first reflective diary for the semester.\tAgency 2',
#  'Good start.\tSensemaking 1',
#  'Kindly refer to the Moodle specifications and examples to improve your reflection.\tAgency 1',
#  "You will get better with time, don't worry.\tAgency 3",
#  'It would have been interesting to know HOW you applied the learning from the first studio in the second studio of the week and WHAT was the difference in how the new team mates responded.\tSensemaking 1',
#  'Could you feel the positive impact with this approach?Try and reflect upon on a previous situation, if any, where you have experienced a similar problem and how you went about it.\tImpact 1',
#  'You have mentioned the action plan, but would have been better to also include some deeper reflection on what your personal involvement was in the situation and the measurable impact in doing so.\tSensemaking 1',
#  'Hope this helps." 45\tAgency 3',
#  '',
#  'I hope you get well soon.\tAgency 3',
#  'Take care of yourself and your health first. 65\tAgency 3',
#  '',
#  '"Hi Leo,Proud of you.\tAgency 3',
#  'All the best for your future!\tAgency 3',
#  ';Thanks,Lee" 100\tAgency 3',
#  '',
#  '"Thanks for the diary.\tAgency 3',
#  'Instead of describing the steps you took for a particular process throughout the reflection, you should reflect more on the emotion or the behavioural change that you experienced going through it and use the same to make an action plan.-VT" 55\tImpact 1',
#  '',
#  'Late Submission. 0\tSensemaking 2',
#  '',
#  'Excellent DIARY Gayathri.; 90\tAgency 2',
#  '',
#  'No Submission 0\tSensemaking 2',
#  '',
#  'Hi Shuaipeng:Please make sure you talk to us before rejecting all the ideas the mentor give.\tAgency 1',
#  'I O',
#  "t is not really good to not to take feedbacks without valid reasonings. And the mentor won't be happy with this if it is not taken properly; 65\tImpact 1",
#  '',
#  '"Thanks for the diary.#Agency 3*[@]Instead of describing the steps you took for finding the data throughout the reflection, you should reflect more on the emotion or the behavioural change that you experienced going through it and use the same to make an action plan.-VT" 55\tImpact 1',
#  '',
#  '"Hi Kaifeng,Good work, Please remember to communicate and work with your teammates, you are a good team.\tAgency 2&Impact 2',
#  'Please balance the work and make sure the high performance of the task.\tImpact 2',
#  'Thanks and regrads,Lee" 65\tAgency 3',
#  '',
#  'good; work; 85\tAgency 2',
#  '',
#  '"Hi Chen,Good work! Please keep in communication and express your thinking, everyone in the team needs to be more responsible for the project.\tAgency 2&Impact 2',
#  'Keep up your good work and work in the team.\tAgency 2&Impact 2',
#  'All the best!\tAgency 3',
#  'Thanks and regards,Lee" 85\tAgency 3',
#  '',
#  'late submission.\tSensemaking 2',
#  'Make sure to submit before the deadline.\tImpact 2',
#  'Good luck. 0\tAgency 3',
#  '',
#  'Please let us know the more detailed info if you are comfortable to share that.. 70\tImpact 3',
#  '',
#  '"thank you - great work\tAgency 3&Agency 2',
#  'however;How did you contribute to the problem statement?\tImpact 1',
#  'how will you address the next steps?\tImpact 1',
#  'what is action in ensuring tasks are not overdue?\tImpact 1',
#  'if so , what are you going to do about it?\tImpact 1',
#  'please ensure all the challenges you can forsee, you come up with a suggestion on how you think you can resolve it.\tImpact 1',
#  'Please consider to reflect on your learnings and what challenges you can forsee and what you action or;how will you contribute to the team rather than listing on the activities you did." 65\tImpact 1',
#  '',
#  '"Hi Shuoran,The reflective diary is not just describe something you have done or you have learnt.\tSensemaking 2',
#  'Remember, we were in the studio with you, and we know what happened in the studio.\tImpact 1',
#  'For the reflective thinking and analysis, try to use a few sentences to describe a few important incidents and then focus on;what did you;feel, why did you have that feeling and what needs to improve to help your team.\tImpact 1',
#  'Besides, try to reflect deeply on how these learnings can help your team and your project.\tImpact 1',
#  'For the action plan, you need to have some strategies to overcome some incidents which happened before, for example, if a similar issue occurs in the future, what actions will you take or what can you do to avoid this happen again." 55\tImpact 1',
#  '',
#  'Late submission 0\tSensemaking 2',
#  '',
#  '"Please make sure you tell your teammate about the issues, they won\'t know unless you tell them.\tImpact 1',
#  ';Please avoid using strong words too" 75\tImpact 1',
#  '',
#  '"Good Luck and best wishes from Mansi, me, and the whole teaching team!" 70\tAgency 3',
#  '',
#  'Good Job on the reflection.\tAgency 2',
#  'just try to make it more concise.-VT 70\tImpact 1',
#  '',
#  'Late Submission. 0\tSensemaking 2',
#  '',
#  '"Hi Qian,Congrats to you!\tAgency 3',
#  'All the best for your future.\tAgency 3',
#  'Thanks,Lee" 100\tAgency 3',
#  '',
#  '"Thanks for the diary.\tAgency 3',
#  'Instead of describing the steps you took for finding the data throughout the reflection, you should reflect more on the emotion or the behavioural change that you experienced going through it and use the same to make an action plan.-VT" 55\tImpact 1',
#  '',
#  '"Hi Yujie,Please submit your next diary on time cause we are not able to give mark for the late submission." 0\tImpact 2',
#  '',
#  'Late Submission 0\tSensemaking 2',
#  '',
#  'No Submission 0\tSensemaking 2',
#  '',
#  '"Hi,Great job on submitting your first reflective diary for the semester.\tAgency 3',
#  'This was a great reflection.\tAgency 2',
#  'Just a suggestion to improve - Maybe also spend some time discussing the internal functioning of the group and your experience with it as you go. For example, you mentioned the possibility of a language barrier issue and the steps you would take as a team as time progresses. Was there any significant contribution from your end at the time that you thought would should be applied during the meeting and how did everyone react to that? Was there a previous experience to a similar situation that you may have faced and the steps you took personally to help overcome that challenge?\tImpact 1',
#  ';Hope this helps." 85\tAgency 3',
#  '',
#  '"Be confident Wei, you shall be able to slowly catch up regardless of whether you are BIS or not.\tImpact 3&Agency 3',
#  'Do not think about speed of learning or your degree, but think about how much you can help your teammate.;" 80\tImpact 3',
#  '',
#  '"Hi Jianxing, You have mentioned the team has to handle the shortcoming but how ? that is what which will be your action plan. " 60\tSensemaking 1&Impact 1',
#  '',
#  'Thanks for sharing.\tAgency 3',
#  "It's amazing to hear to your experience and journey with this unit.\tAgency 3",
#  'All the best for your future endeavours.\tAgency 3',
#  'Keep in touch. 85\tAgency 3',
#  '',
#  'No Submission 0\tSensemaking 2',
#  '',
#  'Please let us know if you cannot make a decision so that we can give recommendations.; 85\tAgency 1',
#  '',
#  '"Thanks for the diary.\tAgency 3',
#  'Instead of describing the steps that you took throughout the reflection, you should reflect more on the emotion or the behavioural change that you experienced going through it and use the same to make an action plan.-VT" 55\tImpact 1',
#  '',
#  'Great Job on the reflection.\tAgency 2',
#  'Just try to make action plans for the things you mentioned in the reflection along with other plans.-VT 75\tImpact 1',
#  '',
#  '"Hi qian,Really good reflection for Week6.\tSensemaking 1',
#  'Please keep up your good work.\tAgency 2',
#  'Also please not to upload the PDF, just typing the words in the Moodle directly, because we need to keep record, otherwise I need to download again.\tImpact 2',
#  ';Thanks and all the best,Lee;" 90\tAgency 3',
#  '',
#  '"Thanks for the diary.\tAgency 3',
#  'Good job on the reflection and action plan, just try to make it concise.-VT" 80\tSensemaking 2&Impact 1',
#  '',
#  'Good luck and best wishes for the future it has been a pleasure working with you.P.B. 85\tAgency 3',
#  '',
#  '"Hi Qiuli,Please submit your next diary on time cause we are not able to give marks for the late submission." 0\tImpact 2',
#  '',
#  'Good job Xiaoming.\tAgency 2',
#  'Keep it up.All the best! 70\tAgency 3',
#  '',
#  '"The action plan you mentioned is about the project, not the things you reflected on about the team working together." 70\tSensemaking 1',
#  '',
#  '68 O',
#  '',
#  'Good work! 80\tAgency 2',
#  '',
#  '"Hi;Xin,I can see you\'ve put a lot of effort into this assignment.\tAgency 2',
#  "It's very comprehensive and covers most of the important points.\tSensemaking 2",
#  'It was, however, a little difficult to folow at times.\tSensemaking 1',
#  'The points you make could have been more clearly expressed and succinct.\tSensemaking 1',
#  ';Your Executive Summary was a little unclear and hard to follow. For example the term ""SWOT"" is not defined nor explained.\tSensemaking 1',
#  'You cannot assume your audience already knows what it means. A good exec summary assumes the reader will not read further and therefore includes a succinct summary of the key points and recommendations.\tImpact 1',
#  'Indeed, the term ""SWOT"" is mentioned throughout the report but at no time is it defined for the reader, even in the section ""SWOT Analysis"".\tSensemaking 1',
#  'Having said that, you do cover most of the important discussion points, and you do a quite good job of it.\tSensemaking 1',
#  'I think if you had presented the SWOT analysis in a regular paragraph format (and not in a table), with subheadings such as ""Strength, Weakness, Opportunity Threats"" then it would have made the report more easily readable.\tSensemaking 1',
#  ';Anyway, good effort!\tAgency 2',
#  'All the best for your exam and future endeavours!\tAgency 3',
#  'I really enjoyed teaching you.Peter H" 70\tAgency 3',
#  '',
#  '65 O',
#  '',
#  '"The feedback is constructive and useful.\tSensemaking 1',
#  'It doesn’t just coverwhat needs to be improved but also what the team has done well.\tSensemaking 1',
#  'In the lastbit, suggestion to improve with visual example is very good and helpful.\tSensemaking 1',
#  'What could be improved: Document/Assignment submission should be appropriately named so itis easy to find - including team number and the number for the team beingreviewing.\tImpact 2',
#  'Description of ‘Audience’ is good but require clarity around someof the descriptions. Eg. ‘the page is too long which is good because mentors donot need to scroll down……’. This sentence is contradicting itself.\tSensemaking 1',
#  '· O',
#  'Instead of saying ‘there existproblems or another problem is about….’, you could say ‘while ??? is good itcould be further improved by …‘ This way, you avoid judgement." 70\tImpact 1',
#  '',
#  '"Please refer to verbal feedback during presentation.\tAgency 1',
#  'Very good anlaysis and use of statistics, visuals and examples to support your points.\tSensemaking 1',
#  'Strategy of re-inforcing your points very effective." 73\tSensemaking 1',
#  '',
#  '"Feedback O',
#  'to O',
#  'Consider O',
#  'Read like a business report – in first person (we) and focused on the problem, insights and actionable recommendations on how to address the problem (rather than focused on theory).\tSensemaking 1',
#  'Good structure to support your points including formatting and use of bullet points.\tSensemaking 1',
#  'The report was appropriately aimed at senior management.\tSensemaking 1',
#  'English expression was appropriate.\tSensemaking 1',
#  'Executive summary acted as a stand alone document\tSensemaking 1',
#  'Purpose and objective of the report was clear\tSensemaking 1',
#  'Some of the issues were glossed over.\tSensemaking 1',
#  'The issues should be analysed in enough depth to enable the reader to understand / persuade the reader why the issue is important to the company and what the implications and risks would be for the business.\tImpact 1',
#  'One way to address this is to include case studies or facts of why “issue x” could be a problem.\tImpact 1',
#  'Considering the issues faced by virtual teams, multidisciplinary teams and cross cultural teams is a good way to start structuring your thinking.\tImpact 1',
#  'Challenges were explained so the reader could understand what the implications / problems would be for the organisation\tSensemaking 1',
#  'Recommendations were succinct, useful and delivered in a way that the reader could readily implement." 63\tSensemaking 1',
#  '',
#  '"A very good presentation covering the key aspects of negative and positive impacts.\tSensemaking 2',
#  'Excellent responses to the questions.\tSensemaking 2',
#  'Areas to improve are listed below.\tAgency 1',
#  'No outline slide is an issue.\tSensemaking 1',
#  'Need to introduce thetopics to be discussed and who is going to discuss what.\tImpact 1',
#  'Forthe stakeholders, it is important to also mention businesses, especially thatyou gave an example of 7-eleven implementation of facial recognition. Otherwise, your example is irrelevant.\tImpact 1',
#  ';It isgreat that you had examples of facial recognition used in Australia and whatbenefits they can bring.\tSensemaking 1',
#  'I would separate the Australian government from lawenforcement. Unless you think they represent one entity, I would not list themas separate stakeholders.\tImpact 1',
#  ';Needto give an introduction to the ethical design framework. Other students mightnot know what it is" 76\tImpact 1',
#  '',
#  '"Some useful suggestions, however, it\'s important that you also give detailed feedback - explain why the changes suggested would be beneficial / are needed in order to help the other team understand how to implement the feedback.\tImpact 1',
#  ';Some general hints on giving constructive feedback:Be specific and give reasons – explain your feedback: To help the person understand why it should change\tImpact 1',
#  'Don’t judge: Describe what could be done differently rather than state what is “good / bad / wrong / right”\tImpact 1',
#  'Be helpful: Offer suggestions for improvement" 63\tImpact 1',
#  '',
#  '"A very good presentation where genuine issues were discussed and a clear conclusion is provided.\tSensemaking 2&Sensemaking 1',
#  'See my comments below.\tAgency 1',
#  'I suggest giving a bit more details ofthe content in terms of who is going to talk about what.\tImpact 1',
#  'The introduction was a bit too quick and content could be richer as the slide onlyhad “algorithm?”\tSensemaking 1&Impact 1',
#  'Needto set a context at the beginning and narrow down the topic so thatstakeholders are more specific.\tImpact 1',
#  'However,it is good that you discussed the positive aspects and relate that to thestakeholders.\tSensemaking 1',
#  'A very good examples when discussing the negative aspects.\tSensemaking 1',
#  'However, some issues need to be explained such as political polarization.\tImpact 1',
#  'Somegood examples were mentioned but I would like them to be listed in slides andexplained especially when it comes to reporting surveys and facts." 68.4\tSensemaking 1&Impact 1',
#  '',
#  'Good work team!\tAgency 2',
#  'Really good to showcase the product features and there is a clear storyline on video.\tSensemaking 1',
#  'The final cut video is a significant improvement on your 1st cut.\tSensemaking 2',
#  'I appreciate the effort. 69\tAgency 2',
#  '',
#  '"Agenda; Agenda and minutes submitted as a single document.\tSensemaking 1',
#  'A good agenda on a separate document should include the date, time, location, attendees and the chairperson for the meeting so there is no confusion.\tImpact 1',
#  'To ensure your meeting is effective it is important the objective of the meeting is obvious. This could be included in the heading or as a separate section at the top of the meeting. For example: To seek feedback from our Industry mentor on what is working well and what needs to be done differently with our project but obviously it needs to be done in a separate document.\tImpact 1',
#  ';Minutes: The key basics of the minutes are good\tSensemaking 1',
#  'Template could have beenbetter.\tSensemaking 1',
#  "It's worth having a look at other templateoptions to see if this template is the best fit for the purpose of your minutes/ your content.\tImpact 1",
#  'Team members or other stakeholders who could not attend themeeting need to understand from the minutes.\tImpact 1',
#  'GENERAL O',
#  'HINTS: O',
#  'A couple of general hints for agendas and minutes:;Agenda:Why important: A good agenda ensures there is a clear objective for the meeting and that the discussion flows in a logical order to achieve that objective within the time allocated.What information should be included in the agenda:\tImpact 1',
#  ';The basics: The first key part is the basics to ensure there is no confusion for attendees: Date, time, location, attendees and who is chairing the meeting.;\tImpact 1',
#  ';The objective: The next critical part is the objective, this can be included in the title of the meeting and / or included in the top of the agenda if more details are needed.\tImpact 1',
#  ';Discussion points: The next component is listing the points to be discussed. These can be done as statement or questions, for example, “Determining stakeholder needs” or “how do we understand our stakeholders needs?”. It is important that the points to be discussed are described in a way that is obvious to attendees of what is needing to be achieved. It is also important that they are listed in order of priority if unrelated or ordered in the most logical flow to achieve the objective of the meeting. This is particularly relevant where drawing out information or decisions are needed to make sense of the next point for discussion.\tImpact 1',
#  'What other information should be included:Prework is assigned if relevant: The agenda should also set out any preparation required of the attendees so they come prepared and decisions can be made more thoroughly and efficiently.\tImpact 1',
#  'Names are allocated to each discussion point: This will depend on the objective and type of meeting. Names should be allocated to a discussion point if there is an expectation that a particular attendee will facilitate or lead that section of the discussion.\tImpact 1',
#  ';Broad times are allocated to each discussion point: Similarly, broad times should be allocated to each discussion point or section to help keep the discussion to time and ensure that all key discussion points are covered and the objective achieved.\tImpact 1',
#  '; O',
#  ';Minutes:Why important: Minutes are an important written record of the key outcomes, decisions and actions made during a meeting so the team and anyone unable to attend has an accurate summary of what was agreed and everyone is clear on what actions need to be taken after the meeting.\tImpact 1',
#  ';What information should be communicated in the minutes: The minutes should include:The basics: Who attended the meeting and who couldn’t make it (who was an apology), date, location, chair,Summary of the team’s decisions: Include the critical points and actions that lead to the decision or action item and any other important insights, risks or issues that might be significant to someone who could not attend.Summary of the actions: arising from the meeting including who is responsible for the action and when it needs to be completed.\tImpact 1',
#  'How much to write:;Be as brief and concise as possible. Ask yourself, will point x matter in three weeks time?\tImpact 1',
#  'Structure of minutes:;Choose a template that makes it easy for any member who was absent to understand what they need to know and do.\tImpact 1',
#  'Use bullet points, bold or underline to highlight actions / who / deadline.\tImpact 1',
#  'Compare various templates on the internet and choose the version that suits your team the best.\tAgency 1&Impact 1',
#  'Ensure you have a clear logical meeting agenda for the minutes to be based on.\tImpact 1',
#  'Use agenda headings to make the minutes easier to follow.\tImpact 1',
#  'Keep your minute template consistent for future meetings." 67\tImpact 1',
#  '',
#  'Remember to explain abbreviations such as ML.\tImpact 1',
#  'The advantages of AI need to focus on judgment.\tImpact 1',
#  'Your presentation could have more specifically answered the topic question. 68\tSensemaking 2',
#  '',
#  '"Overall, very good agenda and meetingminute.\tSensemaking 2',
#  'The template is easy to follow.\tSensemaking 1',
#  'What could be improved:-both agenda and meeting minute, nofacilitator identified.\tSensemaking 1',
#  'Time clearly estimated for each agenda item.\tSensemaking 1',
#  'Purpose ofeach agenda item and who is responsible clearly explained.\tSensemaking 1',
#  '-In your attendee list, are all teammembers?\tImpact 1',
#  'Not clear who else is attending the meeting.\tSensemaking 1',
#  '-Objective of the meeting could be clearer.\tImpact 1',
#  'Yes, it is a problem statement presentation, but you could have thought aboutwhat exactly as a team you want to get out of the team or was there something youwanted to focus on and get IM’s feedback on.\tSensemaking 1',
#  'This would also help you framegood questions to ask. - Discussion points/feedback andaction items are very clearly capture, but action items should have estimateddeadlines. You could further improve by organising the discussion points as peragenda item.\tImpact 1',
#  '-One day late submission" 74\tSensemaking 2',
#  '',
#  '"What worked well in your report:Executive summary acted as a stand alone document\tSensemaking 1',
#  'Purpose and objective of the report was clear\tSensemaking 1',
#  'Points were generally well made, practical and insightful.\tSensemaking 1',
#  ';Good structure to support your points.\tSensemaking 1',
#  'Formatting and use of bullet points to keep the report succinct\tSensemaking 1',
#  'Ways to improve:Check the auto-generate format that makes sure no mistake in the title or content\tImpact 1',
#  'Some of the recommendations were very high level and needed further elaboration.It should be clear to the reader what specific actions the reader should take to implement them.\tSensemaking 1&Impact 1',
#  'Some of the issues were glossed over.\tSensemaking 1',
#  'The issues should be analysed in enough depth to enable the reader to understand / persuade the reader why the issue is important to the company and what the implications and risks would be for the business.One way to address this is to include case studies or facts of why “issue x” could be a problem.\tImpact 1',
#  'Considering the issues faced by virtual teams, multidisciplinary teams and cross cultural teams is a good way to start structuring your thinking.;" 64\tImpact 3',
#  '',
#  '"What worked well in your report:Formatting and use of bullet points to keep the report succinct\tSensemaking 1',
#  'Had great structure and read like a business report, very good exec summary structure, the challenges were very well made ( focused on multicultural and communication issues).\tSensemaking 1',
#  'Executive summary acted as a stand-alone document\tSensemaking 1',
#  'The purpose and objective of the report was clear\tSensemaking 1',
#  'Ways to improve:A number of key challenges/insights critical to the success of high performing teams could be there\tImpact 1',
#  "Implications of Tuckman's stages of team development - eg. the Realisation that previously high performing / productive teams may revert back to forming or storming stages as a result of new team members and losing productivity.\tImpact 1",
#  'New teams go through multiple stages before achieving high performance. If measures are not put in place there is a risk that teams may not evolve past conflict and remain dysfunctional (storming) etc etc.\tImpact 1',
#  'Elaboration on why the Z Process is important to consider – ie. risk that the new teams no longer have the complementary workflow strengths/skills needed to complete their projects successfully (mix of creators, advancers, refiners and executors).\tImpact 1',
#  'Thank you Nivedha, good luck with your final exam!" 74\tAgency 3',
#  '',
#  'Very good work in addressing the issues raised based on the first cut video.\tSensemaking 1',
#  'The audio is making it more interesting now and it is good that you have highlighted some other important features in your application.\tSensemaking 1',
#  'Good luck with the expo. 74\tAgency 3',
#  '',
#  '"Well done presentation.\tAgency 2',
#  ';Good introduction and context provided.\tSensemaking 1',
#  'The team did have cohesiveness and had a flow in the presentation as a team and was catchy.\tSensemaking 1',
#  ';The slides were good and had a minimalistic design.\tSensemaking 1',
#  ';The stakeholders positively and negatively impacted were well identified.\tSensemaking 1',
#  'Could have highlighted more the ethical aspects in the positive impact, well done in the concerns.\tSensemaking 1',
#  ';The agenda should have been added\tImpact 1',
#  'The conclusion should have had the Ethical dilemma part clearly mentioned about regulations on AI.;" 80\tSensemaking 1',
#  '',
#  'Provided some useful suggestions.\tSensemaking 1',
#  'It does not just cover whatneeds to be improved but also what the team has done well.\tSensemaking 1',
#  'The additionalfeedback in the last section was detailed and useful.\tSensemaking 1',
#  'What could be improved:Good you tried empathising withthe audience-IM. It would have been even better if you further triedunderstanding their needs and behaviour-what they would prefer to see on thesite.\tSensemaking 1&Impact 1',
#  'Describe what could be donedifferently rather than state what is “good / bad / wrong / right” as you didin parts of your feedback.\tImpact 1',
#  'Keep your feedback free of judgement. 68\tImpact 1',
#  '',
#  'Please find theattached feedback for the first cut of your product video below: 79\tAgency 1',
#  '',
#  '"What worked well in your report:Read like a business report – focused on the problem, insights and actionable recommendations on how to address the problem\tSensemaking 1',
#  'Executive summary acted as a stand alone document\tSensemaking 1',
#  'Purpose and objective of the report was clear\tSensemaking 1',
#  'Points were generally well made, practical and insightful.\tSensemaking 1',
#  ';Good structure to support your points.\tSensemaking 1',
#  'Formatting and use of bullet points to keep the report succinct\tSensemaking 1',
#  'Ways to improve:Some of the recommendations were very high level and needed further elaboration. It should be clear to the reader what specific actions the reader should take to implement them.\tSensemaking 1&Impact 1',
#  'Some of the issues were glossed over.\tSensemaking 1',
#  'The issues should be analysed in enough depth to enable the reader to understand / persuade the reader why the issue is important to the company and what the implications and risks would be for the business. One way to address this is to include case studies or facts of why “issue x” could be a problem.\tImpact 1',
#  'Considering the issues faced by virtual teams, multidisciplinary teams and cross cultural teams is a good way to start structuring your thinking.\tImpact 3',
#  'The focus should be on the practical application of the theory - not the theory itself.\tImpact 1',
#  'The report should be focused on the problem and practical solutions / insights to help the reader understand and address that problem. " 73\tImpact 2',
#  '',
#  '"Good agenda, however missing chairperson,\tSensemaking 1',
#  'Minutes could have been better.\tSensemaking 1',
#  'The discussion did not recorded properly.\tSensemaking 1',
#  '; No need to record who said what, record key points; and outcomes.\tImpact 1',
#  'The next steps also did not stated clearly.\tSensemaking 1',
#  'How to improve:Agenda:Why important: Agood agenda ensures there is a clear objective for the meeting and that thediscussion flows in a logical order to achieve that objective within the timeallocated.\tImpact 1',
#  'What informationshould be included in the agenda: The basics: Thefirst key part is the basics to ensure there is no confusion for attendees:Date, time, location, attendees and who is chairing the meeting.\tImpact 1',
#  '; The objective: Thenext critical part is the objective, this can be included in the title of themeeting and / or included in the top of the agenda if more details are needed.\tImpact 1',
# ...
#  'What informationshould be communicated in the minutes: The minutes should include:The basics: Whoattended the meeting and who couldn’t make it (who was an apology), date,location, chair,Summary of theteam’s decisions: Include the critical points and actions that lead to thedecision or action item and any other important insights, risks or issues thatmight be significant to someone who could not attend.Summary of theactions: arising from the meeting including who is responsible for the actionand when it needs to be completed.\tImpact 1',
#  'How much to write:Be as brief and concise as possible.\tImpact 1',
#  'Ask yourself, will point x matter in threeweeks time?\tImpact 3',
#  'Structure ofminutes: Choose a template that makes it easy for any member who was absent tounderstand what they need to know and do.\tImpact 1',
#  'Use bullet points, bold or underlineto highlight actions / who / deadline.\tImpact 1',
#  'Compare various templates on theinternet and choose the version that suits your team the best.\tAgency 1',
#  'Ensure you havea clear logical meeting agenda for the minutes to be based on.\tImpact 1',
#  'Use agendaheadings to make the minutes easier to follow.\tImpact 1',
#  'Keep your minute templateconsistent for future meetings.;;" 35\tImpact 2',
#  '',
#  'Well done.\tAgency 2',
#  'Good job on incorporating the feedback. 68\tSensemaking 2',
#  '',
#  '"What worked well in your report:Read like a business report – focused on the problem, insights and actionable recommendations on how to address the problem\tSensemaking 2&Sensemaking 1',
#  'Executive summary acted as a stand alone document\tSensemaking 1',
#  'Purpose and objective of the report was clear\tSensemaking 1',
#  'Points were generally well made, practical and insightful.\tSensemaking 1',
#  'Good structure to support your points.\tSensemaking 1',
#  'Formatting and use of bullet points to keep the report succinct\tSensemaking 1',
#  'Ways to improve:Some of the recommendations were very high level and needed further elaboration. It should be clear to the reader what specific actions the reader should take to implement them.you could include examples or case studies for some of the broader recommendations so the reader knows how to implement." 76\tSensemaking 1&Impact 1',
#  '',
#  '"Agenda: O',
#  '(30/50) O',
#  'The agenda is a stand-alone document, sent out before the meeting and contains the discussion points and time allocated for each point.\tImpact 1',
#  'The structure of the agenda needs improvement.\tImpact 1',
#  'The purpose of the meeting is clear through the agenda points in the minutes.\tSensemaking 1',
#  'The meeting details are present, though the location, in this case, the online zoom meeting, is not specified.\tSensemaking 1',
#  'Minutes: O',
#  '(30/50) O',
#  'The discussion points are not included and the minute allocation of the points is missing as well.\tSensemaking 1',
#  'The action items are mentioned along with the person responsible, but the due date for the task is missing.\tSensemaking 1',
#  'The action items highlighted are not mapped to the feedback received, and so is missing context. " 60\tSensemaking 1',
#  '',
#  '"Executive summary somewhat acted as a stand alone documentand covered significant points completely without requiring the reader read onin order to make sense of them.\tSensemaking 1',
#  'Remember, you want to mention all points covered, not some (but succinctly, the section may be slightly over formatted with all the headers)\tImpact 1&Sensemaking 1',
#  'Remember the audience and purpose of a business report.This is not an essay. The focus should be on the practical application of thetheory - not the theory itself.\tImpact 3&Impact 2',
#  'The report should be focused on the problem andpractical solutions / insights to help the reader understand and address thatproblem.\tImpact 2',
#  'The reader should be able to walk away with practical and tangible recommendationsthey can implement.\tImpact 1',
#  'So listing out the Z process, DMIS, Tuckmans high vs low context (and explaining the theory extensively, is not what a business report is about)\tSensemaking 1',
#  'You can apply the learnings they provide, but fleshing out their ins and outs is a little too much. So just the key characteristics of each would suffice if they were tied in together.\tImpact 1&Sensemaking 1',
#  '""Results and Findings"" as a section header is a telling sign that it is more of an academic paper than a business report.\tSensemaking 1',
#  'Recommendationswere succinct, useful, very practical and delivered in a way that the reader could readilyimplement.\tSensemaking 1',
#  'Though there seems to be repetition of recommendations in different sections, its best to break them up to where they belong.\tSensemaking 1&Impact 1',
#  'A conclusion isn\'t another executive summary, think of it as a closing introduction with general key takeaways.;" 75\tImpact 1',
#  '',
#  '"Great job, Matthew.\tAgency 2',
#  'Purpose and objective of the report was clear, with good structure to support your points.\tSensemaking 1',
#  'Recommendations were succinct, useful and delivered in a way that the reader could readily implement.\tSensemaking 1',
#  'Read like a business report – in first person and focused on the problem, insights and actionable recommendations on how to address the problem .\tSensemaking 2&Sensemaking 1',
#  'Very professional!\tSensemaking 1',
#  'One small criticism - in your Executive Summary you could have included some general details about the actual issue you are providing advice upon eg: the acquisition of a competitor with offices based in India, China, and the US and the plan to establish new global multidisciplinary teams etc\tSensemaking 1',
#  'Well done!\tAgency 2',
#  'All the best for your exam and future endeavours!\tAgency 3',
#  'Thanks for your thoughful contributions during our tutorials throughout the semester.\tAgency 3',
#  'I really enjoyed teaching you.Peter H" 82\tAgency 3',
#  '',
#  '"Feedback O',
#  'to O',
#  'Consider O',
#  'Does not really read like a business report.\tSensemaking 2',
#  'Good structure to support your points including formatting and use of bullet points.\tSensemaking 1',
#  'Ensure your report is written for your audience - it needs to be focused on the needs of a senior executive in your organisation, not your Monash tutor.\tImpact 3',
#  'Check your English expression through a third party before submitting to ensure your message can be clearly understood.\tAgency 1',
#  'The executive summary did not act completely as a stand alone document that could be read separately from the report.\tSensemaking 1',
#  'A good exec summary assumes the reader will not read further and therefore includes a succinct summary of the key points and recommendations.\tImpact 1',
#  'The report should clearly include the purpose of the report (either in the introduction or in a separate section). In this case, to provide insights into the key characteristics of a high performing team; the potential challenges that may prevent the new global teams from performing; and recommendations for how the company should address these potential challenges.\tImpact 1',
#  'Some of the issues were glossed over.\tSensemaking 1',
#  'The issues should be analysed in enough depth to enable the reader to understand / persuade the reader why the issue is important to the company and what the implications and risks would be for the business. One way to address this is to include case studies or facts of why “issue x” could be a problem.\tImpact 1',
#  'Considering the issues faced by virtual teams, multidisciplinary teams and cross cultural teams is a good way to start structuring your thinking.\tImpact 3',
#  'Remember the audience and purpose of a business report.\tImpact 3',
#  'This is not an essay. The focus should be on the practical application of the theory - not the theory itself.\tImpact 1',
#  'The report should be focused on the problem and practical solutions / insights to help the reader understand and address that problem.\tImpact 1',
#  'The reader should be able to walk away with practical and tangible recommendations they can implement.\tImpact 3',
#  'Be careful not to overly summarise (gloss) over the recommendations. It should be clear to the reader why they are important and what specific actions the reader should take to implement them. For example, you could include examples or case studies for some of the broader recommendations so the reader knows how to implement.\tImpact 1',
#  'Putting recommendations in a separate section help so that they don’t get “lost” in the report." 50\tImpact 1',
#  '',
#  '"TP6Agenda: O',
#  '(35/50) O',
#  'The meeting objective is highlighted clearly.\tSensemaking 1',
#  'The discussion points are mentioned well in a separate column - clear and concise.\tSensemaking 1',
#  'The structure of the agenda is missing. It is a stand-alone document, sent out/ prepared before the meeting with the key discussion points and the time breakdown.\tSensemaking 1&Impact 1',
#  'A separate Agenda &amp; Minutes are required. Please do not combine the two items.\tImpact 1',
#  'For both Agenda and Minutes you need to include the role of the Attendees, Industry Mentors - Chair Persons &amp; internal Facilitators – Monash Uni mentors\tImpact 1',
#  '; O',
#  "It's great that you add the time/duration to each discussion point.\tSensemaking 1",
#  'For the Outcome/Actions, everyone is responsible appears beyond realistic.; Given the short time span, joint tasks can be allocated.\tSensemaking 1&Impact 1',
#  'Minutes: O',
#  '(38/50) O',
#  'Meeting details, objective and list of attendees is mentioned clearly.\tSensemaking 1',
#  ';The structure of the minutes is good.\tSensemaking 1',
#  ';The discussion points are explained well in the minutes along with the minute breakdown.\tSensemaking 1',
#  'The Agenda items are mapped to all the discussion points as well.\tSensemaking 1',
#  ';The action items are allocated and have clear due dates assigned.\tSensemaking 1',
#  'The action items are not totally mapped to the relevant feedback received.\tSensemaking 1',
#  ';GENERAL HINTS:A couple of general hints for agendas and minutes:Agenda:Whyimportant:;A good agenda ensures there is a clear objective for themeeting and that the discussion flows in a logical order to achieve thatobjective within the time allocated.\tImpact 1',
#  'What informationshould be included in the agenda:o;;;The basics:;The first key part isthe basics to ensure there is no confusion for attendees: Date, time, location,attendees and who is chairing the meeting.\tImpact 1',
#  ';o;;; O',
#  'The objective:;The next criticalpart is the objective, this can be included in the title of the meeting and /or included in the top of the agenda if more details are needed.\tImpact 1',
#  'o;;; O',
#  'Discussion points:;The nextcomponent is listing the points to be discussed. These can be done as statementor questions, for example, “Determining stakeholder needs” or “how do weunderstand our stakeholders needs?”. It is important that the points to bediscussed are described in a way that is obvious to attendees of what isneeding to be achieved. It is also important that they are listed in order ofpriority if unrelated or ordered in the most logical flow to achieve the objectiveof the meeting. This is particularly relevant where drawing out information ordecisions are needed to make sense of the next point for discussion.\tImpact 1',
#  'What otherinformation should be included:O Prework is assigned if relevant:;The agenda shouldalso set out any preparation required of the attendees so they come preparedand decisions can be made more thoroughly and efficiently.\tImpact 1',
#  'o;;; O',
#  'Names are allocated to each discussionpoint:;This will depend on the objective and type of meeting. Namesshould be allocated to a discussion point if there is an expectation that aparticular attendee will facilitate or lead that section of the discussion.\tImpact 1',
#  'o;;; O',
#  'Broad times are allocated to eachdiscussion point:;Similarly, broad times should be allocated to each discussionpoint or section to help keep the discussion to time and ensure that all keydiscussion points are covered and the objective achieved.\tImpact 1',
#  'Minutes: Whyimportant:;Minutes are an important written record of the keyoutcomes, decisions and actions made during a meeting so the team and anyoneunable to attend has an accurate summary of what was agreed and everyone isclear on what actions need to be taken after the meeting.\tImpact 1',
#  '●;;;;;;; O',
#  'What informationshould be communicated in the minutes: The minutes should include: The basics:;Whoattended the meeting and who couldn’t make it (who was an apology), date,location, chair, Summary of theteam’s decisions:;Include the critical points and actions that lead tothe decision or action item and any other important insights, risks or issuesthat might be significant to someone who could not attend. Summary of the actions:arising from the meeting including who is responsible for the action and whenit needs to be completed.\tImpact 1',
#  'How much to write:;Beas brief and concise as possible.\tImpact 1',
#  'Ask yourself, will point x matter in threeweeks time?\tImpact 3',
#  'Structure of minutes:;Choosea template that makes it easy for any member who was absent to understand whatthey need to know and do.\tImpact 1',
#  'Use bullet points, bold or underline to highlightactions / who / deadline.\tImpact 1',
#  'Compare various templates on the internet and choosethe version that suits your team the best.\tAgency 1',
#  'Ensure you have a clear logicalmeeting agenda for the minutes to be based on.\tImpact 1',
#  'Use agenda headings to make theminutes easier to follow.\tImpact 1',
#  'Keep your minute template consistent for futuremeetings." 73\tImpact 2',
#  '',
#  'Please refer to verbal feedback during presentation.\tAgency 1',
#  'Good use of examples to support your arguments.\tSensemaking 1',
#  '; Conclusion was very good but a lot of new content was introduced which would have strengthened your stakeholder arguments had it been introduced earlier.\tSensemaking 1',
#  "Ran overtime which can cause challenges if the audience can't stay. 67\tSensemaking 1",
#  '',
#  'Good work done.\tAgency 2',
#  ';Good job on incorporating the feedback. 66\tSensemaking 2',
#  '',
#  '"What worked well in your report;Points werewell made, practical, and insightful.\tSensemaking 1',
#  'Very good use of examples, case studies,and facts to support your arguments.\tSensemaking 1',
#  'Challenges wereexplained so the reader could understand what the implications/problems wouldbe for the organisation\tSensemaking 1',
#  'Recommendationswere succinct, useful, and delivered in a way that the reader could readilyimplement.\tSensemaking 1',
#  'Good structureto support your points.\tSensemaking 1',
#  'Formatting anduse of bullet points to keep the report succinct\tSensemaking 1',
#  'Ways to improve:·; ;Did not include and Executive summary.\tSensemaking 1',
#  '; O',
#  '; O',
#  '; O',
#  '; O',
#  'Rememberthe audience and purpose of a business report. This is not an essay. The focusshould be on the practical application of the theory - not the theory itself.\tImpact 3&Impact 1',
#  'The report should be focused on the problem and practical solutions/insights tohelp the reader understand and address that problem.\tImpact 2',
#  'The reader should be ableto walk away with practical and tangible recommendations they can implement.\tImpact 2',
#  '·;;;;;;;; O',
#  'Theexecutive summary did not act completely as a stand-alone document that couldbe read separately from the report. A good exec summary assumes the reader willnot read further and therefore includes a succinct summary of the key pointsand recommendations.\tSensemaking 1&Impact 1',
#  '·; O',
#  ...]

# %% [markdown]
# This master list can be converted to a Pandas dataframe as follows:

# %%
# Converting the list of feedback texts into a dataframe
feed_df = pd.DataFrame(full_dat)

# Checking the newly created dataframe
feed_df
# Out:
#                                                        0
# 0      Yuejing more in depth analysis is required and...
# 1
# 2      ﻿Team 1 requested to re-do their workbook 3 to...
# 3      The team submitted the workbook 23 days after ...
# 4
# ...                                                  ...
# 12166  In part (b), which was more complicated than i...
# 12167  Q3: 11.5/13: More English exposition is requir...
# 12168  You made two errors: finding the determinant i...
# 12169  Q4: 5.5/6: The point where the two circles int...
# 12170
#
# [12171 rows x 1 columns]

# %% [markdown]
# As shown above, we have a very unorganized DataFrame. Let us go about making it more readable and creating proper columns. First, let us name this column as follows:

# %%
# Naming the column 
feed_df.columns = ['Sentence']

# Checking the data with the new column name
feed_df
# Out:
#                                                 Sentence
# 0      Yuejing more in depth analysis is required and...
# 1
# 2      ﻿Team 1 requested to re-do their workbook 3 to...
# 3      The team submitted the workbook 23 days after ...
# 4
# ...                                                  ...
# 12166  In part (b), which was more complicated than i...
# 12167  Q3: 11.5/13: More English exposition is requir...
# 12168  You made two errors: finding the determinant i...
# 12169  Q4: 5.5/6: The point where the two circles int...
# 12170
#
# [12171 rows x 1 columns]

# %% [markdown]
# ### 2. Isolating the Rubrics from the Text
#
# In this section, we can define a function that can separate the rubrics from the text and put them into a new column. Each feedback is accompanied by a rubric or rubric combination and separated from it with a `\t`. We will use this to split the data.

# %%
# Defining a function to separate the rubrics from the feedback text
def remRubric(text):

    rubric1 = ''

    if '\t' in text:

        rubric1 = text.split("\t", 1)[1]

    return rubric1

# Applying the rubric separating function to the data
feed_df['Rubric'] = feed_df['Sentence'].apply(lambda x : remRubric(x))

# %%
# Checking the separated rubrics
feed_df
# Out:
#                                                 Sentence
# 0      Yuejing more in depth analysis is required and...  \
# 1
# 2      ﻿Team 1 requested to re-do their workbook 3 to...
# 3      The team submitted the workbook 23 days after ...
# 4
# ...                                                  ...
# 12166  In part (b), which was more complicated than i...
# 12167  Q3: 11.5/13: More English exposition is requir...
# 12168  You made two errors: finding the determinant i...
# 12169  Q4: 5.5/6: The point where the two circles int...
# 12170
#
#                        Rubric
# 0      Sensemaking 1&Impact 1
# 1
# 2                    Impact 1
# 3               Sensemaking 2
# 4
# ...                       ...
# 12166           Sensemaking 1
# 12167                Impact 2
# 12168           Sensemaking 1
# 12169           Sensemaking 1
# 12170
#
# [12171 rows x 2 columns]

# %%
# Printing the new occurrences of rubrics and rubric combinations
print(feed_df['Rubric'].unique())
# Out:
# ['Sensemaking 1&Impact 1' '' 'Impact 1' 'Sensemaking 2' 'Sensemaking 1'
#  'Agency 2&Agency 1' 'Agency 3' 'Agency 2' 'Agency 1' 'Impact 2'
#  'Agency 2&Impact 1' 'Sensemaking 1&Impact 2' 'Agency 2&Sensemaking 1'
#  'Sensemaking 2&Sensemaking 1' 'Sensemaking 2&Impact 2'
#  'Sensemaking 1&Sensemaking 2' 'Impact 1&Impact 2'
#  'Sensemaking 1&Impact 3' 'Impact 3' 'Agency 1&Impact 1'
#  'Agency 2&Impact 2' 'Agency 3&Agency 2' 'Impact 3&Agency 3'
#  'Sensemaking 2&Impact 1' 'Impact 1&Sensemaking 1'
#  'Sensemaking 1&Agency 1' 'Impact 3&Impact 2' 'Impact 3&Impact 1'
#  'Impact 1&Impact 3' 'Impact 2&Impact 1' 'Impact 1&Agency 2'
#  'Agency 2&Sensemaking 2' 'Sensemaking 1&Agency 2'
#  'Impact 2&Sensemaking 1' 'Agency 2&Agency 3' 'Sensemaking 2&Agency 2'
#  'Agency 1&Sensemaking 1' 'Impact 3&Sensemaking 1' 'Agency 1&Impact 2'
#  'Agency 3&Sensemaking 1' 'Sensemaking 2&Agency 3'
#  'Agency 2&Sensemaking 1&Impact 1' 'Sensemaking 2&Agency 1'
#  'Agency 2&Sensemaking 1&Agency 1' 'Sensemaking 2&Sensemaking 1&Impact 1'
#  'Sensemaking 1&Impact 1&Agency 2']

# %% [markdown]
# There is a lot of non-feedback text in between the feedback comments. This kind of text is not labelled with any rubric. Therefore, the corresponding value in the new Rubric column will be NULL. Therefore, we need to drop these rows from the dats as they do not contribute to the analysis that will be conducted subsequently.

# %%
# Filtering the empty rubric values from the data
feed_df = feed_df[feed_df['Rubric'] != '']

# Resetting the index of the dataframe
feed_df = feed_df.reset_index(drop = True)

# Checking the unique rubric values in the filtered dataframe
print(feed_df['Rubric'].unique())
# Out:
# ['Sensemaking 1&Impact 1' 'Impact 1' 'Sensemaking 2' 'Sensemaking 1'
#  'Agency 2&Agency 1' 'Agency 3' 'Agency 2' 'Agency 1' 'Impact 2'
#  'Agency 2&Impact 1' 'Sensemaking 1&Impact 2' 'Agency 2&Sensemaking 1'
#  'Sensemaking 2&Sensemaking 1' 'Sensemaking 2&Impact 2'
#  'Sensemaking 1&Sensemaking 2' 'Impact 1&Impact 2'
#  'Sensemaking 1&Impact 3' 'Impact 3' 'Agency 1&Impact 1'
#  'Agency 2&Impact 2' 'Agency 3&Agency 2' 'Impact 3&Agency 3'
#  'Sensemaking 2&Impact 1' 'Impact 1&Sensemaking 1'
#  'Sensemaking 1&Agency 1' 'Impact 3&Impact 2' 'Impact 3&Impact 1'
#  'Impact 1&Impact 3' 'Impact 2&Impact 1' 'Impact 1&Agency 2'
#  'Agency 2&Sensemaking 2' 'Sensemaking 1&Agency 2'
#  'Impact 2&Sensemaking 1' 'Agency 2&Agency 3' 'Sensemaking 2&Agency 2'
#  'Agency 1&Sensemaking 1' 'Impact 3&Sensemaking 1' 'Agency 1&Impact 2'
#  'Agency 3&Sensemaking 1' 'Sensemaking 2&Agency 3'
#  'Agency 2&Sensemaking 1&Impact 1' 'Sensemaking 2&Agency 1'
#  'Agency 2&Sensemaking 1&Agency 1' 'Sensemaking 2&Sensemaking 1&Impact 1'
#  'Sensemaking 1&Impact 1&Agency 2']

# %%
# Checking if the rubrics have been properly split from the data
print(feed_df[~feed_df["Sentence"].str.contains('\t')])
# Out:
# Empty DataFrame
# Columns: [Sentence, Rubric]
# Index: []

# %% [markdown]
# Now that we have split the rubrics from the data and put them in a new column, we can remove them from the feedback text. The below function replaces every instance of `\t` and a rubric with a whitespace character.

# %%
# Defining a function to remove the rubric from the feedback text
def remLabel(string):
    
        # Splitting the rubric from the text
        label = string.split("\t", 1)[1]
        
        # Replacing the rubric from the text with blank
        new_string = string.replace(label, "" )
        
        # Replacing 
        new_string1 = new_string.replace('\t', '')

        return new_string1

# Applying the rubric removal function to the data
feed_df['SentenceLabelRem'] = feed_df['Sentence'].apply(lambda x : remLabel(x))

# %% [markdown]
# We were able to successfully spit the rubrics from the text and put them into another column. The next step we will perform is to split the score from the text. It must be noted that not every row contains the score. The score represents the final marking for the student for one piece of feedback. However, one piece of feedback is spread out over multiple rows.
#
# Therefore, we must split the score, put it in a new column and then duplicate it across all the rows that are part of the same feedback. Since the score is the last comment of the text, we can split it relatively easily.

# %%
# Splitting the last word from the data
feed_df['Score'] = feed_df['SentenceLabelRem'].apply(lambda x: x.split(' ')[-1])

# Checking the data
feed_df
# Out:
#                                                Sentence
# 0     Yuejing more in depth analysis is required and...  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is requir...
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
#                       Rubric
# 0     Sensemaking 1&Impact 1  \
# 1                   Impact 1
# 2              Sensemaking 2
# 3              Sensemaking 1
# 4          Agency 2&Agency 1
# ...                      ...
# 5754                Impact 1
# 5755           Sensemaking 1
# 5756                Impact 2
# 5757           Sensemaking 1
# 5758           Sensemaking 1
#
#                                        SentenceLabelRem      Score
# 0     Yuejing more in depth analysis is required and...      58.33  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...        55.
# 2     The team submitted the workbook 23 days after ...         59
# 3     Risk assessment and report needs work as discu...         70
# 4     "Good effort, Please refer to detailed feedbac...  attached.
# ...                                                 ...        ...
# 5754  Q2: 6.5/7 Need to use more English to communic...       (d).
# 5755  In part (b), which was more complicated than i...      else.
# 5756  Q3: 11.5/13: More English exposition is required.  required.
# 5757  You made two errors: finding the determinant i...       (e).
# 5758  Q4: 5.5/6: The point where the two circles int...      83.78
#
#                                        SentenceScoreRem
# 0     Yuejing more in depth analysis is required and...
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is required.
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
# [5759 rows x 5 columns]

# %% [markdown]
# In a similar operation that was conducted to remove the rubrics from the feedback text, we will now define a function that removes the score from the feedback text, since we have successfully separated it and placed it in another column. It is important to remove it completely from the feedback text after separation since we don't want it to be analysed as a part of the text by the NLP, machine learning or deep learning techiques later.

# %%
# Defining a function to remove the score from the feedback text.
def remScore(text):
    
    # Splitting the last word from the feedback text
    last = text.split(' ')[-1]
    
    # Checking if the last word is a number
    if last.isnumeric() or re.match(r'^-?\d+(?:\.\d+)$', last) is not None:
        
        # Replacing the numerical value in the text with whitespace
        text = text.replace(last, "" )
    
    # Returning the text with the value removed
    return text

feed_df['SentenceScoreRem'] = feed_df['SentenceLabelRem'].apply(lambda x : remScore(x))

# %%
# Checking the data
feed_df
# Out:
#                                                Sentence
# 0     Yuejing more in depth analysis is required and...  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is requir...
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
#                       Rubric
# 0     Sensemaking 1&Impact 1  \
# 1                   Impact 1
# 2              Sensemaking 2
# 3              Sensemaking 1
# 4          Agency 2&Agency 1
# ...                      ...
# 5754                Impact 1
# 5755           Sensemaking 1
# 5756                Impact 2
# 5757           Sensemaking 1
# 5758           Sensemaking 1
#
#                                        SentenceLabelRem      Score
# 0     Yuejing more in depth analysis is required and...      58.33  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...        55.
# 2     The team submitted the workbook 23 days after ...         59
# 3     Risk assessment and report needs work as discu...         70
# 4     "Good effort, Please refer to detailed feedbac...  attached.
# ...                                                 ...        ...
# 5754  Q2: 6.5/7 Need to use more English to communic...       (d).
# 5755  In part (b), which was more complicated than i...      else.
# 5756  Q3: 11.5/13: More English exposition is required.  required.
# 5757  You made two errors: finding the determinant i...       (e).
# 5758  Q4: 5.5/6: The point where the two circles int...      83.78
#
#                                        SentenceScoreRem
# 0     Yuejing more in depth analysis is required and...
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is required.
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
# [5759 rows x 5 columns]

# %% [markdown]
# If we take a closer look at the new `Score` column, we can see that there are several instances where the last word of the feedback text was not the score. Therefore, we have a lot of non-numeric values in the `Score` column. The idea is to remove them completely and then duplicate them with the next occuring numeric value.
#
# For example, we have values like '(d)', 'else.' and 'required' in the above view of the data. The next occuring numeric value is 83.78. Therefore, we need to replace these values with 83.78 as they all belong to the same feedback.
#
# Therefore, we will define a function to replace the non-numeric values with a whitespace.
#
# Some of the values in the Score column also contains the character `.`. Therefore, we also need to make sure that these values are left as it is and then we can remove it separately.

# %%
# Erasing the non-numeric values in the Score column
def remNonNumeric(text):
    
    # Using regular expressions to replace the non-numeric values with whitespace
    rem = re.sub(r'[^0-9.]', '', text)
    
    # Returning the replaced values
    return rem

# Applying the non-numeric value removal function to the Score column
feed_df['Score'] = feed_df['Score'].apply(lambda x : remNonNumeric(x))

# %%
# Replacing the single punctuation with a whitespace
feed_df['Score'] = feed_df['Score'].replace('.','')

# %%
# Checking the data
feed_df
# Out:
#                                                Sentence
# 0     Yuejing more in depth analysis is required and...  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is requir...
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
#                       Rubric
# 0     Sensemaking 1&Impact 1  \
# 1                   Impact 1
# 2              Sensemaking 2
# 3              Sensemaking 1
# 4          Agency 2&Agency 1
# ...                      ...
# 5754                Impact 1
# 5755           Sensemaking 1
# 5756                Impact 2
# 5757           Sensemaking 1
# 5758           Sensemaking 1
#
#                                        SentenceLabelRem  Score
# 0     Yuejing more in depth analysis is required and...  58.33  \
# 1     ﻿Team 1 requested to re-do their workbook 3 to...    55.
# 2     The team submitted the workbook 23 days after ...     59
# 3     Risk assessment and report needs work as discu...     70
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...    ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is required.
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...  83.78
#
#                                        SentenceScoreRem
# 0     Yuejing more in depth analysis is required and...
# 1     ﻿Team 1 requested to re-do their workbook 3 to...
# 2     The team submitted the workbook 23 days after ...
# 3     Risk assessment and report needs work as discu...
# 4     "Good effort, Please refer to detailed feedbac...
# ...                                                 ...
# 5754  Q2: 6.5/7 Need to use more English to communic...
# 5755  In part (b), which was more complicated than i...
# 5756  Q3: 11.5/13: More English exposition is required.
# 5757  You made two errors: finding the determinant i...
# 5758  Q4: 5.5/6: The point where the two circles int...
#
# [5759 rows x 5 columns]

# %% [markdown]
# Our stage 1 data is ready. Next, we will export this data to a `csv` file. These new whitespace rows will be replaced with the next occuring numeric value in Excel. Furthermore, we will add a new column called `FeedbackCode` in excel. The file we end up with in the second stage is called `stage2.csv` and it can be found in the same directory as this notebook.

# %%
# Exporting the stage 1 data to a csv file.
feed_df[['SentenceLabelRem', 'SentenceScoreRem', 'Rubric', 'Score']].to_csv('./LabelledFeedback/stage1.csv')
